# %%
import pandas as pd

# %%
df = pd.read_csv('/home/jovyan/Prak ML/quiz 2_1197050136_Soniawan/chn-population.csv', index_col='Unnamed: 0')
df.columns.name='Year'

# %%
df.head()
# Out:
# Year  At the end of the total population (ten thousand people)  \
# 2021                                             141260
# 2020                                             141212
# 2019                                             141008
# 2018                                             140541
# 2017                                             140011
#
# Year  The male population (ten thousand people)  \
# 2021                                      72311
# 2020                                      72357
# 2019                                      72039
# 2018                                      71864
# 2017                                      71650
#
# Year  Female population (ten thousand people)  \
# 2021                                    68949
# 2020                                    68855
# 2019                                    68969
# 2018                                    68677
# 2017                                    68361
#
# Year  Urban population (ten thousand people)  \
# 2021                                   91425
# 2020                                   90220
# 2019                                   88426
# 2018                                   86433
# 2017                                   84343
#
# Year  Rural population (ten thousand people)
# 2021                                   49835
# 2020                                   50992
# 2019                                   52582
# 2018                                   54108
# 2017                                   55668

# %%
print(df.dtypes)
# Out:
# Year
# At the end of the total population (ten thousand people)    int64
# The male population (ten thousand people)                   int64
# Female population (ten thousand people)                     int64
# Urban population (ten thousand people)                      int64
# Rural population (ten thousand people)                      int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73 entries, 2021 to 1949
# Data columns (total 5 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   At the end of the total population (ten thousand people)  73 non-null     int64
#  1   The male population (ten thousand people)                 73 non-null     int64
#  2   Female population (ten thousand people)                   73 non-null     int64
#  3   Urban population (ten thousand people)                    73 non-null     int64
#  4   Rural population (ten thousand people)                    73 non-null     int64
# dtypes: int64(5)
# memory usage: 3.4 KB

# %%
df.describe()
# Out:
# Year   At the end of the total population (ten thousand people)  \
# count                                          73.000000
# mean                                       102979.383562
# std                                         28271.718602
# min                                         54167.000000
# 25%                                         76368.000000
# 50%                                        105851.000000
# 75%                                        129227.000000
# max                                        141260.000000
#
# Year   The male population (ten thousand people)  \
# count                                  73.000000
# mean                                52929.726027
# std                                 14414.860351
# min                                 28145.000000
# 25%                                 39115.000000
# 50%                                 54725.000000
# 75%                                 66556.000000
# max                                 72357.000000
#
# Year   Female population (ten thousand people)  \
# count                                73.000000
# mean                              50049.643836
# std                               13859.803827
# min                               26022.000000
# 25%                               37253.000000
# 50%                               51126.000000
# 75%                               62671.000000
# max                               68969.000000
#
# Year   Urban population (ten thousand people)  \
# count                               73.000000
# mean                             34245.178082
# std                              25664.214559
# min                               5765.000000
# 25%                              13548.000000
# 50%                              25094.000000
# 75%                              52376.000000
# max                              91425.000000
#
# Year   Rural population (ten thousand people)
# count                               73.000000
# mean                             68734.191781
# std                              12361.612994
# min                              48402.000000
# 25%                              55668.000000
# 50%                              70518.000000
# 75%                              80174.000000
# max                              85947.000000

# %%
df.count()
# Out:
# Year
# At the end of the total population (ten thousand people)    73
# The male population (ten thousand people)                   73
# Female population (ten thousand people)                     73
# Urban population (ten thousand people)                      73
# Rural population (ten thousand people)                      73
# dtype: int64

# %%
df.describe(include='all')
# Out:
# Year   At the end of the total population (ten thousand people)  \
# count                                          73.000000
# mean                                       102979.383562
# std                                         28271.718602
# min                                         54167.000000
# 25%                                         76368.000000
# 50%                                        105851.000000
# 75%                                        129227.000000
# max                                        141260.000000
#
# Year   The male population (ten thousand people)  \
# count                                  73.000000
# mean                                52929.726027
# std                                 14414.860351
# min                                 28145.000000
# 25%                                 39115.000000
# 50%                                 54725.000000
# 75%                                 66556.000000
# max                                 72357.000000
#
# Year   Female population (ten thousand people)  \
# count                                73.000000
# mean                              50049.643836
# std                               13859.803827
# min                               26022.000000
# 25%                               37253.000000
# 50%                               51126.000000
# 75%                               62671.000000
# max                               68969.000000
#
# Year   Urban population (ten thousand people)  \
# count                               73.000000
# mean                             34245.178082
# std                              25664.214559
# min                               5765.000000
# 25%                              13548.000000
# 50%                              25094.000000
# 75%                              52376.000000
# max                              91425.000000
#
# Year   Rural population (ten thousand people)
# count                               73.000000
# mean                             68734.191781
# std                              12361.612994
# min                              48402.000000
# 25%                              55668.000000
# 50%                              70518.000000
# 75%                              80174.000000
# max                              85947.000000

# %%
df.fillna(0)
# Out:
# Year  At the end of the total population (ten thousand people)  \
# 2021                                             141260
# 2020                                             141212
# 2019                                             141008
# 2018                                             140541
# 2017                                             140011
# ...                                                 ...
# 1953                                              58796
# 1952                                              57482
# 1951                                              56300
# 1950                                              55196
# 1949                                              54167
#
# Year  The male population (ten thousand people)  \
# 2021                                      72311
# 2020                                      72357
# 2019                                      72039
# 2018                                      71864
# 2017                                      71650
# ...                                         ...
# 1953                                      30468
# 1952                                      29833
# 1951                                      29231
# 1950                                      28669
# 1949                                      28145
#
# Year  Female population (ten thousand people)  \
# 2021                                    68949
# 2020                                    68855
# 2019                                    68969
# 2018                                    68677
# 2017                                    68361
# ...                                       ...
# 1953                                    28328
# 1952                                    27649
# 1951                                    27069
# 1950                                    26527
# 1949                                    26022
#
# Year  Urban population (ten thousand people)  \
# 2021                                   91425
# 2020                                   90220
# 2019                                   88426
# 2018                                   86433
# 2017                                   84343
# ...                                      ...
# 1953                                    7826
# 1952                                    7163
# 1951                                    6632
# 1950                                    6169
# 1949                                    5765
#
# Year  Rural population (ten thousand people)
# 2021                                   49835
# 2020                                   50992
# 2019                                   52582
# 2018                                   54108
# 2017                                   55668
# ...                                      ...
# 1953                                   50970
# 1952                                   50319
# 1951                                   49668
# 1950                                   49027
# 1949                                   48402
#
# [73 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73 entries, 2021 to 1949
# Data columns (total 5 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   At the end of the total population (ten thousand people)  73 non-null     int64
#  1   The male population (ten thousand people)                 73 non-null     int64
#  2   Female population (ten thousand people)                   73 non-null     int64
#  3   Urban population (ten thousand people)                    73 non-null     int64
#  4   Rural population (ten thousand people)                    73 non-null     int64
# dtypes: int64(5)
# memory usage: 3.4 KB

# %%
df['At the end of the total population (ten thousand people)'] = df['At the end of the total population (ten thousand people)'].fillna(0)
df['The male population (ten thousand people)'] = df['The male population (ten thousand people)'].fillna(0)
df['Female population (ten thousand people)'] = df['Female population (ten thousand people)'].fillna(0)
df['Urban population (ten thousand people)'] = df['Urban population (ten thousand people)'].fillna(0)
df['Rural population (ten thousand people)'] = df['Rural population (ten thousand people)'].fillna(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73 entries, 2021 to 1949
# Data columns (total 5 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   At the end of the total population (ten thousand people)  73 non-null     int64
#  1   The male population (ten thousand people)                 73 non-null     int64
#  2   Female population (ten thousand people)                   73 non-null     int64
#  3   Urban population (ten thousand people)                    73 non-null     int64
#  4   Rural population (ten thousand people)                    73 non-null     int64
# dtypes: int64(5)
# memory usage: 3.4 KB

# %%
df.describe(include='all')
# Out:
# Year   At the end of the total population (ten thousand people)  \
# count                                          73.000000
# mean                                       102979.383562
# std                                         28271.718602
# min                                         54167.000000
# 25%                                         76368.000000
# 50%                                        105851.000000
# 75%                                        129227.000000
# max                                        141260.000000
#
# Year   The male population (ten thousand people)  \
# count                                  73.000000
# mean                                52929.726027
# std                                 14414.860351
# min                                 28145.000000
# 25%                                 39115.000000
# 50%                                 54725.000000
# 75%                                 66556.000000
# max                                 72357.000000
#
# Year   Female population (ten thousand people)  \
# count                                73.000000
# mean                              50049.643836
# std                               13859.803827
# min                               26022.000000
# 25%                               37253.000000
# 50%                               51126.000000
# 75%                               62671.000000
# max                               68969.000000
#
# Year   Urban population (ten thousand people)  \
# count                               73.000000
# mean                             34245.178082
# std                              25664.214559
# min                               5765.000000
# 25%                              13548.000000
# 50%                              25094.000000
# 75%                              52376.000000
# max                              91425.000000
#
# Year   Rural population (ten thousand people)
# count                               73.000000
# mean                             68734.191781
# std                              12361.612994
# min                              48402.000000
# 25%                              55668.000000
# 50%                              70518.000000
# 75%                              80174.000000
# max                              85947.000000

# %%
df.corr()
# Out:
# Year                                                At the end of the total population (ten thousand people)  \
# Year
# At the end of the total population (ten thousan...                                           1.000000
# The male population (ten thousand people)                                                    0.999900
# Female population (ten thousand people)                                                      0.999892
# Urban population (ten thousand people)                                                       0.899383
# Rural population (ten thousand people)                                                       0.419831
#
# Year                                                The male population (ten thousand people)  \
# Year
# At the end of the total population (ten thousan...                                   0.999900
# The male population (ten thousand people)                                            1.000000
# Female population (ten thousand people)                                              0.999586
# Urban population (ten thousand people)                                               0.898546
# Rural population (ten thousand people)                                               0.421341
#
# Year                                                Female population (ten thousand people)  \
# Year
# At the end of the total population (ten thousan...                                 0.999892
# The male population (ten thousand people)                                          0.999586
# Female population (ten thousand people)                                            1.000000
# Urban population (ten thousand people)                                             0.900063
# Rural population (ten thousand people)                                             0.418172
#
# Year                                                Urban population (ten thousand people)  \
# Year
# At the end of the total population (ten thousan...                                0.899383
# The male population (ten thousand people)                                         0.898546
# Female population (ten thousand people)                                           0.900063
# Urban population (ten thousand people)                                            1.000000
# Rural population (ten thousand people)                                           -0.019181
#
# Year                                                Rural population (ten thousand people)
# Year
# At the end of the total population (ten thousan...                                0.419831
# The male population (ten thousand people)                                         0.421341
# Female population (ten thousand people)                                           0.418172
# Urban population (ten thousand people)                                           -0.019181
# Rural population (ten thousand people)                                            1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

korelasi = df.corr()
plt.figure(figsize=(15, 10))
sns.heatmap(korelasi[(korelasi >= 0.5) | (korelasi <= -0.4)], cmap='viridis', vmax=1.0, vmin=-1.0, linewidths=0.1, 
            annot=True, annot_kws={"size": 8}, square=True).set_title('Korelasi Antar Variabel')
plt.show()

# %%
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(style = "dark")

# %%
df_urban=df[['Urban population (ten thousand people)','Rural population (ten thousand people)']]

# %%
plt.figure(figsize=(21,9))
sns.lineplot(data=df_urban)
plt.title("China's Urban and Rural population in total")
plt.legend()
